# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/navneetnivu07/dviz/blob/master/distribution.ipynb)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
sns.set(color_codes=True)

# %%
x = np.random.normal(size=100000000)
sns.distplot(x);
